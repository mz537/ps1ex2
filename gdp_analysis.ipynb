# %% [markdown]
# # GDP Analysis (2002-2022)
#
# In this notebook, we will import the data processing and plotting functions, load the GDP data for selected countries, and visualize the GDP trends over time.

# %%
# Import the data fetching and plotting functions
import sys


from data import fetch_gdp_data
from plot_utils import plot_gdp

# %%
#executive the functions#

countries = ['GB', 'JP', 'CN', 'DE', 'CH']
gdp_data = fetch_gdp_data(countries, start_year=2002, end_year=2022, output_file='gdp_data.csv')

# Display the first few rows of the fetched data
print(gdp_data.head())

#plot the gdp 
countries1 = ['China', 'Germany', 'Japan', 'Switzerland', 'United Kingdom']

plot_gdp("gdp_data.csv", countries1, output_file='gdp_plot.png')
# Out:
#    country       date       GDP
# 85   China 2002-01-01  1.470558
# 84   China 2003-01-01  1.660281
# 83   China 2004-01-01  1.955347
# 82   China 2005-01-01  2.285961
# 81   China 2006-01-01  2.752119

# %% [markdown]
# From here we can see that China has a huge rise in GDP during the 20 years, from lower than 2 trillion to nearly 20 trillon dorllars.
# Japan's GDP rised until 2012 then dropped to the same level as 2002.
# Both Germany and UK's GDP have increased slightly with fluctuation during the 20 years.
# Switzerland has a steady and slight increase in its GDP during the period.
